# %% [markdown]
# # 빅데이터 과제 Beautiful soup 사용.
#
# ### 크롤링할 내용 컬럼은 (카테고리 , 시/군/구 , 올린시각 , 상품이름 , 상품상태 , 상품태그)

# %%
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd

# %%
result = [] #결과를 저장할 list 
page = 12
url = 'http://www.alba.co.kr/job/area/MainLocal.asp?page=%d&pagesize=50&viewtype=L&sidocd=031&gugun=%BD%C3%C8%EF%BD%C3,&dong=%C0%FC%C3%BC&d_area=&d_areacd=&strAreaMulti=031%7C%7C%BD%C3%C8%EF%BD%C3%7C%7C%C0%FC%C3%BC%2C&hidJobKind=&hidJobKindMulti=&WorkTime=&searchterm=&AcceptMethod=&ElecContract=&HireTypeCD=&CareerCD=&CareercdUnRelated=&LastSchoolCD=&LastSchoolcdUnRelated=&GenderCD=&GenderUnRelated=&AgeLimit=0&AgeUnRelated=&PayCD=&PayStart=&WelfareCD=&Special=&WorkWeekCD=&WeekDays=&hidSortCnt=50&hidSortOrder=&hidSortDate=&WorkPeriodCD=&hidSort=&hidSortFilter=Y&hidListView=LIST&WsSrchKeywordWord=&hidWsearchInOut=&hidSchContainText='
url.replace
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html, 'html.parser')
#print(html)
print(soup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-a8834efeba6f> in <module>
#       1 result = [] #결과를 저장할 list
#       2 page = 12
# ----> 3 url = 'http://www.alba.co.kr/job/area/MainLocal.asp?page=%d&pagesize=50&viewtype=L&sidocd=031&gugun=%BD%C3%C8%EF%BD%C3,&dong=%C0%FC%C3%BC&d_area=&d_areacd=&strAreaMulti=031%7C%7C%BD%C3%C8%EF%BD%C3%7C%7C%C0%FC%C3%BC%2C&hidJobKind=&hidJobKindMulti=&WorkTime=&searchterm=&AcceptMethod=&ElecContract=&HireTypeCD=&CareerCD=&CareercdUnRelated=&LastSchoolCD=&LastSchoolcdUnRelated=&GenderCD=&GenderUnRelated=&AgeLimit=0&AgeUnRelated=&PayCD=&PayStart=&WelfareCD=&Special=&WorkWeekCD=&WeekDays=&hidSortCnt=50&hidSortOrder=&hidSortDate=&WorkPeriodCD=&hidSort=&hidSortFilter=Y&hidListView=LIST&WsSrchKeywordWord=&hidWsearchInOut=&hidSchContainText='%(page)
#       4 html = urllib.request.urlopen(url)
#       5 soup = BeautifulSoup(html, 'html.parser')
#
# TypeError: not enough arguments for format string

# %%
title = soup.select_one('#NormalInfo > table > tbody ')
#print(title)
print(title.get_text())
# Out:
# 시흥시 정왕동
#
# 잡솔루션[남/녀생산직]삼성폴더블노트/생산조립검사/370/전자반도체/TV전기차/기숙사
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 08:30~20:30
# 월급3,500,000
# 04/09
#
#
#
#
# 시흥시 정왕동
#
# 주식회사 티넷텔레콤상담원 & 영업사원 모집 / 주5일근무/ 기본급185만원+인센티브
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 09:00~18:00
# 연봉22,000,000
# 04/09
#
#
#
#
# 시흥시 정왕동
#
# 부르미【시흥 배곧 정왕동 】배달대행/월500만이상/전동자전거/렌탈/여성환영
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 시간협의
# 월급5,000,000
# 04/09
#
#
#
#
# 시흥시 대야동
#
# 홍진테크(주)초보환영 바로근무가능 점심제공 물류입출고 및 상하차및택배포장아르바이트모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 09:00~18:00
# 시급8,720
# 18시간전
#
#
#
#
# 시흥시 은행동
#
# (주)달콩이네리빙[온라인 쇼핑몰] CS 및 운영보조 관리 사무직
#
# 스크랩
# 요약보기
# 새창보기
#
# 전자근로계약서
#
# 09:00~18:00
# 연봉24,000,000
# 04/08
#
#
#
#
# 시흥시 정왕동
#
# 노브랜드 시흥아울렛점[이마트] No-Brand 시흥아울렛점 스태프 모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 10:00~22:00 (로테이션)
# 시급9,990
# 18시간전
#
#
#
#
# 시흥시 전체
#
# 쿠팡원하는 요일/단기알바/초보가능/쿠팡플렉스
#
# 스크랩
# 요약보기
# 새창보기
# 리뷰점수 8점 작성된 리뷰의 좋아요 수를 10점 만점으로 표시한 점수입니다.
#
# 시간협의
# 시급17,000
# 03/31
#
#
#
#
# 시흥시 대야동
#
# 법무법인청연법무법인청연-내근,외근
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 09:00~18:00
# 월급1,850,000
# 04/08
#
#
#
#
# 시흥시 전체
#
# 쿠팡원하는 요일/단기알바/초보가능/쿠팡플렉스
#
# 스크랩
# 요약보기
# 새창보기
# 리뷰점수 8점 작성된 리뷰의 좋아요 수를 10점 만점으로 표시한 점수입니다.
#
# 시간협의
# 시급17,000
# 04/07
#
#
#
#
# 시흥시 전체
#
# 모델하우스[내근/상담직][월2,000/기본급有] 큰돈 벌고싶으면 주저말고 지원하세요
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 10:00~18:00
# 월급5,000,000
# 18시간전
#
#
#
#
# 시흥시 전체
#
# COUPANG쿠팡친구 채용(주5일/연차15일/쿠팡소속직원/차량지원)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 시간협의
# 연봉35,000,000
# 04/02
#
#
#
#
# 시흥시 배곧동
#
# 다이소 배곧신도시점[다이소/신입가능/주6일/2시간/단기알바]다이소배곧신도시점 알바 모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 19:30~21:30
# 시급9,000
# 04/09
#
#
#
#
# 시흥시 정왕동
#
# 미래와사람대기업1차협력업체 남녀생산직모집 100%취업 월300만원이상가능
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 09:00~18:00
# 월급3,000,000
# 04/09
#
#
#
#
# 시흥시 정왕본동
#
# (주)일을찾는사람들시화공단 누구나 할수있는일  월요일 근무가능 남,여 모집 당일 지급
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 08:00~17:00
# 시급9,500
# 04/09
#
#
#
#
# 시흥시 대야동
#
# 아소비 부천시흥지사주4일.시흥 대야역 두산위브 더 파크에 거주하시고 아소비공부방 운영가능하신분
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 14:00~18:00
# 월급2,000,000
# 04/08
#
#
#
#
# 시흥시 대야동
#
# 아소비 부천시흥지사주4일.시흥 센트럴푸르지오에 거주하시고, 아소비공부방 운영 가능하신분
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 14:00~18:00
# 월급2,000,000
# 04/08
#
#
#
#
# 시흥시 정왕동
#
# 버거킹 시흥정왕점[시흥정왕점]  나이트 크루 모집
#
# 스크랩
# 요약보기
# 새창보기
# 리뷰점수 9점 작성된 리뷰의 좋아요 수를 10점 만점으로 표시한 점수입니다.
#
# 23:00~07:00
# 시급8,720
# 04/08
#
#
#
#
# 시흥시 정왕동
#
# 버거킹 시흥정왕점[시흥정왕점]  크루 대(大) 모집
#
# 스크랩
# 요약보기
# 새창보기
# 리뷰점수 9점 작성된 리뷰의 좋아요 수를 10점 만점으로 표시한 점수입니다.
#
# 시간협의
# 시급8,720
# 04/07
#
#
#
#
# 시흥시 대야동
#
# 반올림피자샵 시흥 은행대야점반올림피자샵시흥은행대야점에서함께할주말알바모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 12:30~16:30
# 시급8,720
# 04/07
#
#
#
#
# 시흥시 대야동
#
# 반올림피자샵 시흥 은행대야점반올림피자샵시흥은행대야점에서함께할주말알바모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 12:30~16:30
# 시급8,720
# 04/07
#
#
#
#
# 시흥시 대야동
#
# 반올림피자샵 시흥 은행대야점반올림피자샵시흥은행대야점에서함께할주말라이더모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 05:00~23:00
# 시급10,000
# 04/07
#
#
#
#
# 시흥시 대야동
#
# 반올림피자샵 시흥 은행대야점반올림피자샵시흥은행대야점에서함께할주말라이더모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 05:00~23:00
# 시급10,000
# 04/07
#
#
#
#
# 시흥시 정왕동
#
# (주)다옴건설【알바그만하고 월500이상 벌어요~】분양상담사/신입사원모집/초보대환영
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 10:00~18:00
# 월급5,000,000
# 04/09
#
#
#
#
# 시흥시 전체
#
# 노브랜드 시흥목감점노브랜드 시흥목감점 STAFF 모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 08:00~22:00 (로테이션)
# 시급9,990
# 04/08
#
#
#
#
# 시흥시 정왕동
#
# 명품구제나라[정왕동] 명품구제샵 옷가게 여직원 모집 (40대환영/격일근무)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 10:30~20:30
# 시급8,720
# 18시간전
#
#
#
#
# 시흥시 전체
#
# 한솔교육 시흥지점시흥 한솔공부방 원장님 모집 (무료창업)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 13:00~18:00
# 월급2,000,000
# 04/08
#
#
#
#
# 시흥시 조남동
#
# CU 목감LH13단지점주말(토/일) 오전 타임 스태프 모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 08:00~16:00
# 시급8,720
# 9시간전
#
#
#
#
# 시흥시 조남동
#
# CU 목감LH13단지점주말 저녁 타임 스태프 모집(경력자 우대)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 16:00~23:00
# 시급8,720
# 9시간전
#
#
#
#
# 시흥시 신천동
#
# 롯데리아 시흥제일점롯데리아 시흥제일점에서 아르바이트(메이트) 모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 18:00~22:30 (로테이션)
# 시급8,720
# 38분전
#
#
#
#
# 시흥시 신천동
#
# 롯데리아 시흥제일점롯데리아 시흥제일점에서 아르바이트(메이트) 모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 18:00~22:30 (로테이션)
# 시급8,720
# 38분전
#
#
#
#
# 시흥시 신천동
#
# 롯데리아 시흥제일점롯데리아 시흥제일점에서 아르바이트(메이트) 모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 18:00~22:30 (로테이션)
# 시급8,720
# 38분전
#
#
#
#
# 시흥시 신천동
#
# 롯데리아 시흥제일점롯데리아 시흥제일점에서 아르바이트(메이트) 모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 18:00~22:30 (로테이션)
# 시급8,720
# 38분전
#
#
#
#
# 시흥시 신천동
#
# 롯데리아 시흥제일점롯데리아 시흥제일점에서 아르바이트(메이트) 모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 18:00~22:30 (로테이션)
# 시급8,720
# 38분전
#
#
#
#
# 시흥시 조남동
#
# CU 목감LH13단지점주중 저녁 타임 스태프 모집(경력자 우대)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 18:00~23:00
# 시급8,720
# 9시간전
#
#
#
#
# 시흥시 조남동
#
# CU 목감LH13단지점주중 심야 타임 스태프 모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 23:00~08:00
# 시급8,720
# 9시간전
#
#
#
#
# 시흥시 조남동
#
# CU 목감LH13단지점주말(금/토) 심야 타임 스태프 모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 23:00~08:00
# 시급8,720
# 9시간전
#
#
#
#
# 시흥시 대야동
#
# 더본코리아 한신포차 시흥대야점시흥대야 한신포차에서 직원 모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 16:00~22:30
# 시급8,720
# 49분전
#
#
#
#
# 시흥시 대야동
#
# 웅진씽크빅 시흥지국시흥시 월곶 재택 스마트올 선생님을 모십니다 (회원보장, 창업 최고 지원혜택
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 시간협의
# 월급2,000,000
# 04/09
#
#
#
#
# 시흥시 대야동
#
# GS25은계미림점GS25 은계미림점 평일 목,금 스토어매니저 모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 시간협의
# 시급8,720
# 04/09
#
#
#
#
# 시흥시 대야동
#
# 웅진씽크빅 시흥지국시흥 은계지구 신입주지역 방문선생님을 모십니다 (회원보장, 초보가능)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 시간협의
# 월급2,000,000
# 04/09
#
#
#
#
# 시흥시 대야동
#
# (주)네오에쓰앤씨카니발(투석환자) 운전자 모집합니다
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 06:00~16:00
# 월급2,000,000
# 04/09
#
#
#
#
# 시흥시 거모동
#
# 영진에프앤에스치킨바베큐 주방.서빙 구합니다
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 18:00~24:00
# 시급8,720
# 5시간전
#
#
#
#
# 시흥시 대야동
#
# GS25은계미림점GS25 은계미림점평일월,화,수 스토어매니저 모집
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 시간협의
# 시급8,720
# 04/09
#
#
#
#
# 시흥시 정왕동
#
# 얼맥당 배곧점스몰비어 얼맥당 시흥배곧점/주중(월~목) 홀및 멀티근무
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 19:00~22:30
# 시급8,800
# 04/09
#
#
#
#
# 시흥시 정왕1동
#
# 강신옥홀서빙 및 조리 주말알바 구함
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 11:00~10:00
# 시급8,720
# 1시간전
#
#
#
#
# 시흥시 은행동
#
# 성원아이북랜드 시흥영업본부성원아이북랜드 책읽어주기 선생님 모집 합니다.(자격증 취득의 기회 제공)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 14:00~20:00
# 건별35,000
# 04/07
#
#
#
#
# 시흥시 신천동
#
# 성원아이북랜드 시흥영업본부성원아이북랜드 책읽어주기 선생님 모집 합니다.(자격증 취득의 기회 제공)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 14:00~20:00
# 건별35,000
# 04/07
#
#
#
#
# 시흥시 대야동
#
# 성원아이북랜드 시흥영업본부성원아이북랜드 책읽어주기 선생님 모집 합니다.(자격증 취득의 기회 제공)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 14:00~20:00
# 건별35,000
# 04/07
#
#
#
#
# 시흥시 은행동
#
# 홍콩반점0410 시흥은계점[홍콩반점 시흥은계점] 홀서빙 직원 구함/240이상(경력인정 협의 가능)
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 10:00~22:00
# 월급2,400,000
# 04/07
#
#
#
#
# 시흥시 정왕동
#
# 육화몽육화몽에서 서빙아르바이트생 모집합니다.
#
# 스크랩
# 요약보기
# 새창보기
#
#
# 18:00~23:00
# 시급9,000
# 1시간전
